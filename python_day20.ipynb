# %% [markdown]
# # Data Analysis of Titanic Dataset

# %%
# !pip install seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("titanic.csv")

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Shape of data

# %%
df1.shape
# Out:
# (891, 12)

# %% [markdown]
# # Top 10 Rows

# %%
df1.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# # Bottom 10 Rows

# %%
df1.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # Describe the data

# %%
df_describe = df1.describe()
df_describe
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Data Cleaning

# %%
age_array = np.array(df1['Age'])
age_array
# Out:
# array([22.  , 38.  , 26.  , 35.  , 35.  ,   nan, 54.  ,  2.  , 27.  ,
#        14.  ,  4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  ,   nan,
#        31.  ,   nan, 35.  , 34.  , 15.  , 28.  ,  8.  , 38.  ,   nan,
#        19.  ,   nan,   nan, 40.  ,   nan,   nan, 66.  , 28.  , 42.  ,
#          nan, 21.  , 18.  , 14.  , 40.  , 27.  ,   nan,  3.  , 19.  ,
#          nan,   nan,   nan,   nan, 18.  ,  7.  , 21.  , 49.  , 29.  ,
#        65.  ,   nan, 21.  , 28.5 ,  5.  , 11.  , 22.  , 38.  , 45.  ,
#         4.  ,   nan,   nan, 29.  , 19.  , 17.  , 26.  , 32.  , 16.  ,
#        21.  , 26.  , 32.  , 25.  ,   nan,   nan,  0.83, 30.  , 22.  ,
#        29.  ,   nan, 28.  , 17.  , 33.  , 16.  ,   nan, 23.  , 24.  ,
#        29.  , 20.  , 46.  , 26.  , 59.  ,   nan, 71.  , 23.  , 34.  ,
#        34.  , 28.  ,   nan, 21.  , 33.  , 37.  , 28.  , 21.  ,   nan,
#        38.  ,   nan, 47.  , 14.5 , 22.  , 20.  , 17.  , 21.  , 70.5 ,
# ...

# %%
#Lets handle age
age_array = np.array(df1['Age'])

df1 = df1.dropna(subset=['Age'])

df1.shape
# Out:
# (714, 12)

# %%
df1['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
fare_array = np.array(df1['Fare'])
fare_array
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#          8.05  ,  31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,
#         18.    ,   7.225 ,  26.    ,  13.    ,   8.0292,  35.5   ,
#         21.075 ,  31.3875,   7.225 , 263.    ,   7.8792,   7.8958,
#         27.7208, 146.5208,   7.75  ,  10.5   ,  82.1708,  52.    ,
#          7.2292,   8.05  ,  18.    ,  11.2417,   9.475 ,  21.    ,
#          7.8958,  41.5792,   7.8792,   8.05  ,  15.5   ,   7.75  ,
#         21.6792,  17.8   ,  39.6875,   7.8   ,  76.7292,  26.    ,
#         61.9792,  35.5   ,  10.5   ,   7.2292,  27.75  ,  46.9   ,
#          7.2292,  80.    ,  83.475 ,  27.9   ,  27.7208,  15.2458,
#         10.5   ,   8.1583,   7.925 ,   8.6625,  10.5   ,  46.9   ,
#         73.5   ,  14.4542,  56.4958,   7.65  ,   7.8958,   8.05  ,
#         29.    ,  12.475 ,   9.    ,   9.5   ,   7.7875,  47.1   ,
# ...

# %%
fare_array = np.array(df1['Fare'])
df1['Fare'] = df1['Fare'].fillna(13.0)
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_22188\3237400057.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Fare'] = df1['Fare'].fillna(13.0)

# %% [markdown]
# # SibSp

# %%
sib_array = np.array(df1['SibSp'])
df1['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5], dtype=int64)

# %% [markdown]
# # Parch

# %%
sib_array = np.array(df1['Parch'])
df1['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %% [markdown]
# # Gender Handling

# %%
gender_array = np.array(df1['Sex'])
df1['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# # Correlations

# %%
df1['Sex'] = df1['Sex'].replace(['female', 'male'],[0, 1] )

age_fare_corr = df1[['Age', 'Fare']].corr()

age_survive_corr = df1[['Age', 'Survived']].corr()

gender_survive_corr = df1[['Sex', 'Survived']].corr()

class_survival_corr = df1[['Pclass', 'Survived']].corr()
 
age_fare_corr = df1[['Age', 'Fare']].corr()

class_fare_corr = df1[['Pclass', 'Fare']].corr()

sibsp_fare_corr = df1[['SibSp', 'Fare']].corr()

sibsp_survived_corr = df1[['SibSp', 'Survived']].corr()

Parch_survived_corr = df1[['Parch', 'Survived']].corr()

print(age_fare_corr)
print(age_survive_corr)
print(gender_survive_corr)
print(class_survival_corr)
print(age_fare_corr)
print(class_fare_corr)
print(sibsp_fare_corr)
print(sibsp_survived_corr)
print(Parch_survived_corr)
# Out:
#            Age      Fare
# Age   1.000000  0.096067
# Fare  0.096067  1.000000
#                Age  Survived
# Age       1.000000 -0.077221
# Survived -0.077221  1.000000
#                Sex  Survived
# Sex       1.000000 -0.538826
# Survived -0.538826  1.000000
#             Pclass  Survived
# Pclass    1.000000 -0.359653
# Survived -0.359653  1.000000
#            Age      Fare
# Age   1.000000  0.096067
# Fare  0.096067  1.000000
#           Pclass      Fare
# Pclass  1.000000 -0.554182
# Fare   -0.554182  1.000000
#           SibSp      Fare
# SibSp  1.000000  0.138329
# Fare   0.138329  1.000000
#              SibSp  Survived
# SibSp     1.000000 -0.017358
# Survived -0.017358  1.000000
#              Parch  Survived
# Parch     1.000000  0.093317
# Survived  0.093317  1.000000
# C:\Users\harsh\AppData\Local\Temp\ipykernel_22188\2669774842.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
plt.plot(df1['Survived'],df1['Sex'])

# %%
plt.plot(df1['Fare'],df1['Parch'])

# %%
plt.hist(df1['Fare'],bins = 10)
# Out:
# (array([577.,  89.,  28.,   2.,   9.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <BarContainer object of 10 artists>)

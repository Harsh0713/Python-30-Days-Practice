# %% [raw]
# JSON
# 1. JavaScript Object Notation
# 2. It is an exucatble script.
# 3. It is made of text in a programming language

# %%
import json

# %%
f = open("student.json")

# %%
data = json.load(f)

# %%
data
# Out:
# {'student_details': [{'name': 'Nikhil', 'course': 'Python', 'Id': '2653'},
#   {'name': 'Shubham', 'course': 'C++', 'Id': '2654'}]}

# %%
json_f = '{"student": "Nikhil","Course" : "Python"}'

# %%
f2 = json.loads(json_f)

# %%
type(data)
# Out:
# dict

# %%
data = data['student_details']

# %%
data
# Out:
# [{'name': 'Nikhil', 'course': 'Python', 'Id': '2653'},
#  {'name': 'Shubham', 'course': 'C++', 'Id': '2654'}]

# %%
for details in data:
    print(f"Name - {details.get('name')}")
    print(f"Course - {details.get('course')}")
    print(f"ID - {details.get('Id')}")
# Out:
# Name - Nikhil
# Course - Python
# ID - 2653
# Name - Shubham
# Course - C++
# ID - 2654

# %% [raw]
# CSV
# 1. Comma Separated Values
# 2. It can be read in excel
# 3. It is also a format to store data like json

# %%
import csv

# %%
filename = open("Train.csv")

# %%
filename
# Out:
# <_io.TextIOWrapper name='Train.csv' mode='r' encoding='UTF-8'>

# %%
data = csv.DictReader(filename)

# %%
data

# %%
data_list = []
for row in data:
    data_list.append(row)

# %%
data_list
# Out:
# [{'\ufeffID': '1',
#   'Warehouse_block': 'D',
#   'Mode_of_Shipment': 'Flight',
#   'Customer_care_calls': '4',
#   'Customer_rating': '2',
#   'Cost_of_the_Product': '177',
#   'Prior_purchases': '3',
#   'Product_importance': 'low',
#   'Gender': 'F',
#   'Discount_offered': '44',
#   'Weight_in_gms': '1233',
#   'Reached.on.Time_Y.N': '1'},
#  {'\ufeffID': '2',
#   'Warehouse_block': 'F',
#   'Mode_of_Shipment': 'Flight',
#   'Customer_care_calls': '4',
#   'Customer_rating': '5',
#   'Cost_of_the_Product': '216',
#   'Prior_purchases': '2',
#   'Product_importance': 'low',
#   'Gender': 'M',
#   'Discount_offered': '59',
#   'Weight_in_gms': '3088',
#   'Reached.on.Time_Y.N': '1'},
#  {'\ufeffID': '3',
#   'Warehouse_block': 'A',
#   'Mode_of_Shipment': 'Flight',
#   'Customer_care_calls': '2',
#   'Customer_rating': '2',
#   'Cost_of_the_Product': '183',
#   'Prior_purchases': '4',
#   'Product_importance': 'low',
#   'Gender': 'M',
#   'Discount_offered': '48',
# ...

# %%
filename = open("Train.csv")
data2 = csv.reader(filename)

# %%
data2

# %%
data_list = []
for row in data2:
    data_list.append(row)

# %%
data_list
# Out:
# [['\ufeffID',
#   'Warehouse_block',
#   'Mode_of_Shipment',
#   'Customer_care_calls',
#   'Customer_rating',
#   'Cost_of_the_Product',
#   'Prior_purchases',
#   'Product_importance',
#   'Gender',
#   'Discount_offered',
#   'Weight_in_gms',
#   'Reached.on.Time_Y.N'],
#  ['1', 'D', 'Flight', '4', '2', '177', '3', 'low', 'F', '44', '1233', '1'],
#  ['2', 'F', 'Flight', '4', '5', '216', '2', 'low', 'M', '59', '3088', '1'],
#  ['3', 'A', 'Flight', '2', '2', '183', '4', 'low', 'M', '48', '3374', '1'],
#  ['4', 'B', 'Flight', '3', '3', '176', '4', 'medium', 'M', '10', '1177', '1'],
#  ['5', 'C', 'Flight', '2', '2', '184', '3', 'medium', 'F', '46', '2484', '1'],
#  ['6', 'F', 'Flight', '3', '1', '162', '3', 'medium', 'F', '12', '1417', '1'],
#  ['7', 'D', 'Flight', '3', '4', '250', '3', 'low', 'F', '3', '2371', '1'],
#  ['8', 'F', 'Flight', '4', '1', '233', '2', 'low', 'F', '48', '2804', '1'],
#  ['9', 'A', 'Flight', '3', '4', '150', '3', 'low', 'F', '11', '1861', '1'],
# ...

# %%
import pandas as pd

# %%
pd.read_csv("Train.csv")
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
pd.read_json("student.json")
# Out:
#                                      student_details
# 0  {'name': 'Nikhil', 'course': 'Python', 'Id': '...
# 1  {'name': 'Shubham', 'course': 'C++', 'Id': '26...

# %%
from datetime import date,datetime,time,timedelta

# %%
date.today()
# Out:
# datetime.date(2024, 8, 8)

# %%
time_ = time(2,3,4)

# %%
time_
# Out:
# datetime.time(2, 3, 4)

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 8, 8, 22, 3, 24, 453325)

# %%
datetime.now() + timedelta(days = 5)
# Out:
# datetime.datetime(2024, 8, 13, 22, 4, 0, 732939)

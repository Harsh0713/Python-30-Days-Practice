# %% [markdown]
# # Machine Learning
# 1. Supervised Learning - Data is Lablled
#         a. Regression
#             a1. Linear Regression
#             a2. Logistic Regression
#             a3. Multivariate Regression
#         b. Classification
# 2. Umsupervised Learning - Data is non-labelled
# 3. Reinforcement Learning - Semi Supervised

# %%
# !pip install seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("titanic.csv", index_col = False)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.shape
# Out:
# (891, 12)

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df1.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df1['Sex'] = df1['Sex'].replace(['female', 'male'],[0, 1] )

# %%
final_df = df1.drop(columns = ['PassengerId', 'Name', 'Ticket'])

# %%
final_df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0           0       3    1  22.0      1      0   7.2500   NaN        S
# 1           1       1    0  38.0      1      0  71.2833   C85        C
# 2           1       3    0  26.0      0      0   7.9250   NaN        S
# 3           1       1    0  35.0      1      0  53.1000  C123        S
# 4           0       3    1  35.0      0      0   8.0500   NaN        S
# ..        ...     ...  ...   ...    ...    ...      ...   ...      ...
# 886         0       2    1  27.0      0      0  13.0000   NaN        S
# 887         1       1    0  19.0      0      0  30.0000   B42        S
# 888         0       3    0   NaN      1      2  23.4500   NaN        S
# 889         1       1    1  26.0      0      0  30.0000  C148        C
# 890         0       3    1  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # x = input, y = output

# %%
x = final_df[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare']]
x
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare
# 0         3    1  22.0      1      0   7.2500
# 1         1    0  38.0      1      0  71.2833
# 2         3    0  26.0      0      0   7.9250
# 3         1    0  35.0      1      0  53.1000
# 4         3    1  35.0      0      0   8.0500
# ..      ...  ...   ...    ...    ...      ...
# 886       2    1  27.0      0      0  13.0000
# 887       1    0  19.0      0      0  30.0000
# 888       3    0   NaN      1      2  23.4500
# 889       1    1  26.0      0      0  30.0000
# 890       3    1  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
x = final_df[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare']]
y = final_df['Survived']
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
x_train, y_train, x_test, y_test = train_test_split(x, y, test_size = 0.8, random_state = 7)

# %%
x_train
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare
# 629       3    1   NaN      0      0    7.7333
# 288       2    1  42.0      0      0   13.0000
# 589       3    1   NaN      0      0    8.0500
# 790       3    1   NaN      0      0    7.7500
# 841       2    1  16.0      0      0   10.5000
# ..      ...  ...   ...    ...    ...       ...
# 579       3    1  32.0      0      0    7.9250
# 502       3    0   NaN      0      0    7.6292
# 537       1    0  30.0      0      0  106.4250
# 196       3    1   NaN      0      0    7.7500
# 175       3    1  18.0      1      1    7.8542
#
# [178 rows x 6 columns]

# %%
y_train
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare
# 725       3    1  20.0      0      0   8.6625
# 861       2    1  21.0      1      0  11.5000
# 528       3    1  39.0      0      0   7.9250
# 46        3    1   NaN      1      0  15.5000
# 627       1    0  21.0      0      0  77.9583
# ..      ...  ...   ...    ...    ...      ...
# 881       3    1  33.0      0      0   7.8958
# 736       3    0  48.0      1      3  34.3750
# 628       3    1  26.0      0      0   7.8958
# 45        3    1   NaN      0      0   8.0500
# 161       2    0  40.0      0      0  15.7500
#
# [713 rows x 6 columns]

# %%
x_test
# Out:
# 629    0
# 288    1
# 589    0
# 790    0
# 841    0
#       ..
# 579    1
# 502    0
# 537    1
# 196    0
# 175    0
# Name: Survived, Length: 178, dtype: int64

# %%
y_test
# Out:
# 725    0
# 861    0
# 528    0
# 46     0
# 627    1
#       ..
# 881    0
# 736    0
# 628    0
# 45     0
# 161    1
# Name: Survived, Length: 713, dtype: int64

# %%
df1['Sex'] = df1['Sex'].replace(['female', 'male'],[0, 1] )

age_fare_corr = df1[['Age', 'Fare']].corr()

age_survive_corr = df1[['Age', 'Survived']].corr()

gender_survive_corr = df1[['Sex', 'Survived']].corr()

class_survival_corr = df1[['Pclass', 'Survived']].corr()
 
age_fare_corr = df1[['Age', 'Fare']].corr()

class_fare_corr = df1[['Pclass', 'Fare']].corr()

sibsp_fare_corr = df1[['SibSp', 'Fare']].corr()

sibsp_survived_corr = df1[['SibSp', 'Survived']].corr()

Parch_survived_corr = df1[['Parch', 'Survived']].corr()

print(age_fare_corr)
print(age_survive_corr)
print(gender_survive_corr)
print(class_survival_corr)
print(age_fare_corr)
print(class_fare_corr)
print(sibsp_fare_corr)
print(sibsp_survived_corr)
print(Parch_survived_corr)
# Out:
#            Age      Fare
# Age   1.000000  0.096067
# Fare  0.096067  1.000000
#                Age  Survived
# Age       1.000000 -0.077221
# Survived -0.077221  1.000000
#                Sex  Survived
# Sex       1.000000 -0.538826
# Survived -0.538826  1.000000
#             Pclass  Survived
# Pclass    1.000000 -0.359653
# Survived -0.359653  1.000000
#            Age      Fare
# Age   1.000000  0.096067
# Fare  0.096067  1.000000
#           Pclass      Fare
# Pclass  1.000000 -0.554182
# Fare   -0.554182  1.000000
#           SibSp      Fare
# SibSp  1.000000  0.138329
# Fare   0.138329  1.000000
#              SibSp  Survived
# SibSp     1.000000 -0.017358
# Survived -0.017358  1.000000
#              Parch  Survived
# Parch     1.000000  0.093317
# Survived  0.093317  1.000000
# C:\Users\harsh\AppData\Local\Temp\ipykernel_7400\2669774842.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score

# %%
model = LogisticRegression()

# %%
import numpy as np
import pandas as pd

# If x_train is a DataFrame
print(x_train.isnull().sum())  # To see how many NaNs in each column

# If x_train is a NumPy array
print(np.isnan(x_train).sum())  # Total NaNs
# Out:
# Pclass     0
# Sex        0
# Age       34
# SibSp      0
# Parch      0
# Fare       0
# dtype: int64
# Pclass     0
# Sex        0
# Age       34
# SibSp      0
# Parch      0
# Fare       0
# dtype: int64

# %%
age_array = np.array(df1['Age'])
age_array
# Out:
# array([22.  , 38.  , 26.  , 35.  , 35.  , 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  , 31.  , 35.  ,
#        34.  , 15.  , 28.  ,  8.  , 38.  , 19.  , 40.  , 66.  , 28.  ,
#        42.  , 21.  , 18.  , 14.  , 40.  , 27.  ,  3.  , 19.  , 18.  ,
#         7.  , 21.  , 49.  , 29.  , 65.  , 21.  , 28.5 ,  5.  , 11.  ,
#        22.  , 38.  , 45.  ,  4.  , 29.  , 19.  , 17.  , 26.  , 32.  ,
#        16.  , 21.  , 26.  , 32.  , 25.  ,  0.83, 30.  , 22.  , 29.  ,
#        28.  , 17.  , 33.  , 16.  , 23.  , 24.  , 29.  , 20.  , 46.  ,
#        26.  , 59.  , 71.  , 23.  , 34.  , 34.  , 28.  , 21.  , 33.  ,
#        37.  , 28.  , 21.  , 38.  , 47.  , 14.5 , 22.  , 20.  , 17.  ,
#        21.  , 70.5 , 29.  , 24.  ,  2.  , 21.  , 32.5 , 32.5 , 54.  ,
#        12.  , 24.  , 45.  , 33.  , 20.  , 47.  , 29.  , 25.  , 23.  ,
#        19.  , 37.  , 16.  , 24.  , 22.  , 24.  , 19.  , 18.  , 19.  ,
# ...

# %%
 #Lets handle age
age_array = np.array(df1['Age'])

df1 = df1.dropna(subset=['Age'])

df1.shape
# Out:
# (714, 12)

# %%
fare_array = np.array(df1['Fare'])
fare_array
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,  51.8625,
#         21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,   8.05  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  18.    ,  26.    ,
#         13.    ,   8.0292,  35.5   ,  21.075 ,  31.3875, 263.    ,
#         27.7208,  10.5   ,  82.1708,  52.    ,   8.05  ,  18.    ,
#         11.2417,   9.475 ,  21.    ,  41.5792,   7.8792,  17.8   ,
#         39.6875,   7.8   ,  76.7292,  26.    ,  61.9792,  10.5   ,
#          7.2292,  27.75  ,  46.9   ,   7.2292,  80.    ,  83.475 ,
#         27.9   ,  10.5   ,   8.1583,   7.925 ,   8.6625,  10.5   ,
#         46.9   ,  73.5   ,  14.4542,  56.4958,   7.65  ,  29.    ,
#         12.475 ,   9.    ,   9.5   ,  47.1   ,  10.5   ,  15.85  ,
#         34.375 , 263.    ,   8.05  ,   8.05  ,   7.8542,  61.175 ,
#         20.575 ,   7.25  ,  34.6542,  63.3583,  23.    ,  26.    ,
#          7.8958,  77.2875,   8.6542,   7.925 ,   7.8958,   7.65  ,
# ...

# %%
fare_array = np.array(df1['Fare'])
df1['Fare'] = df1['Fare'].fillna(13.0)

# %%
print(x_train.isnull().sum())  # Checks for NaN values in each column
import numpy as np
print(np.isnan(x_train).sum())  # Checks for the total number of NaNs in the array
x_train_filled = x_train.fillna(x_train.mean())  # Fill NaN with mean value of each column
x_train_filled = np.nan_to_num(x_train, nan=np.nanmean(x_train))  # Replace NaNs with mean
x_train_dropped = x_train.dropna()  # Drop rows with NaN values
x_train_cleaned = np.where(np.isinf(x_train), np.nan, x_train)  # Replace infinite values with NaN
x_train_clipped = np.clip(x_train_cleaned, -1e6, 1e6)  # Clip values between -1e6 and 1e6
# Assuming x_train_cleaned is your cleaned data
model.predict(x_train_cleaned)
# Out:
# Pclass     0
# Sex        0
# Age       34
# SibSp      0
# Parch      0
# Fare       0
# dtype: int64
# Pclass     0
# Sex        0
# Age       34
# SibSp      0
# Parch      0
# Fare       0
# dtype: int64
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7400\3845479077.py in <module>
#       8 x_train_clipped = np.clip(x_train_cleaned, -1e6, 1e6)  # Clip values between -1e6 and 1e6
#       9 # Assuming x_train_cleaned is your cleaned data
# ---> 10 model.predict(x_train_cleaned)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     423             Vector containing the class labels for each sample.
#     424         """
# --> 425         scores = self.decision_function(X)
#     426         if len(scores.shape) == 1:
#     427             indices = (scores > 0).astype(int)
#
# ...

# %% [markdown]
# # Above Error not able to solve

# %%
training_results = model.predict(x_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7400\522817716.py in <module>
# ----> 1 training_results = model.predict(x_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     423             Vector containing the class labels for each sample.
#     424         """
# --> 425         scores = self.decision_function(X)
#     426         if len(scores.shape) == 1:
#     427             indices = (scores > 0).astype(int)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
#     405         check_is_fitted(self)
#     406
# --> 407         X = self._validate_data(X, accept_sparse="csr", reset=False)
#     408         scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
# ...

# %%
train_accuracy = accuracy_score(y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7400\1198997270.py in <module>
# ----> 1 train_accuracy = accuracy_score(y_train)
#
# TypeError: accuracy_score() missing 1 required positional argument: 'y_pred'
